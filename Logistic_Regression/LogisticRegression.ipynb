# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cardio_train.csv',sep=';')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
print(df.size)
print(df.shape)
# Out:
# 910000
# (70000, 13)

# %%
df.drop("id",axis=1,inplace=True)

# %%
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
print("{}".format(df.duplicated().sum()))
# Out:
# 24

# %%
df.duplicated().sum()  # Tekrar eden değerleri bulduk
# Out:
# 24

# %%
dp = df[df.duplicated(keep=False)]

# %%
dp
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 1142   17493       2     169    74.0    120     80            1     1      0
# 1204   16793       1     165    68.0    120     80            1     1      0
# 1568   21945       1     165    60.0    120     80            1     1      0
# 1612   20293       1     162    70.0    110     70            1     1      0
# 2305   20495       1     165    70.0    120     80            1     1      0
# 2677   22077       1     175    69.0    120     80            1     1      0
# 6325   14552       1     158    64.0    120     80            1     1      0
# 8190   21778       1     160    58.0    120     80            1     1      0
# 10494  16937       2     170    70.0    120     80            1     1      0
# 10562  20495       1     165    70.0    120     80            1     1      0
# 10777  18988       1     164    65.0    120     80            1     1      0
# ...

# %%
dp = dp.sort_values(by=['age','gender','height'],ascending=False)

# %%
dp
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 2677   22077       1     175    69.0    120     80            1     1      0
# 45748  22077       1     175    69.0    120     80            1     1      0
# 1568   21945       1     165    60.0    120     80            1     1      0
# 48917  21945       1     165    60.0    120     80            1     1      0
# 40301  21943       1     165    65.0    120     80            1     1      0
# 52552  21943       1     165    65.0    120     80            1     1      0
# 8190   21778       1     160    58.0    120     80            1     1      0
# 65622  21778       1     160    58.0    120     80            1     1      0
# 21871  21280       1     165    65.0    120     80            1     1      0
# 45125  21280       1     165    65.0    120     80            1     1      0
# 17168  21230       1     164    62.0    120     80            1     1      0
# ...

# %%
df.drop_duplicates(inplace=True)   # tekrar eden değerleri sildik
df.duplicated().sum()
# Out:
# 0

# %%
# Şimdi aykırı değerleri bulucaz

df.describe().T
# Out:
#                count          mean          std      min      25%      50%  \
# age          69976.0  19468.950126  2467.374620  10798.0  17664.0  19703.0
# gender       69976.0      1.349648     0.476862      1.0      1.0      1.0
# height       69976.0    164.359152     8.211218     55.0    159.0    165.0
# weight       69976.0     74.208519    14.397211     10.0     65.0     72.0
# ap_hi        69976.0    128.820453   154.037729   -150.0    120.0    120.0
# ap_lo        69976.0     96.636261   188.504581    -70.0     80.0     80.0
# cholesterol  69976.0      1.366997     0.680333      1.0      1.0      1.0
# gluc         69976.0      1.226535     0.572353      1.0      1.0      1.0
# smoke        69976.0      0.088159     0.283528      0.0      0.0      0.0
# alco         69976.0      0.053790     0.225604      0.0      0.0      0.0
# active       69976.0      0.803718     0.397187      0.0      1.0      1.0
# ...

# %%
# Diğer gözlemlerden önemli ölçüde farklı olan değerlere aykırı değer deriz. Tansiyon gibi unsurların max değerinin 16000 olması gibi
# Göstermek için boxplot kullanıcaz

# %%
df.head(2)
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.boxplot(x='cardio',y='height',data=df,palette='winter')
plt.subplot(1,2,2)
sns.boxplot(x='cardio',y='weight',data=df,palette='summer')

plt.show()

# %%
df['bmi'] = (df['weight'] / (df['height']/100)**2).round(1)

# %%
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio   bmi
# 0     0       1       0  22.0
# 1     0       1       1  34.9
# 2     0       0       1  23.5
# 3     0       1       1  28.7
# 4     0       0       0  23.0

# %%
# anormal durumları çıkarıcaz
# obez , çok kısa , çok zayıf , çok uzun gibi

df = df[(df['bmi']>10) & (df['bmi']<100)]

# %%
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168    62.0    110     80            1     1      0
# 1  20228       1     156    85.0    140     90            3     1      0
# 2  18857       1     165    64.0    130     70            3     1      0
# 3  17623       2     169    82.0    150    100            1     1      0
# 4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio   bmi
# 0     0       1       0  22.0
# 1     0       1       1  34.9
# 2     0       0       1  23.5
# 3     0       1       1  28.7
# 4     0       0       0  23.0

# %%
df.drop(['height','weight'],axis=1,inplace=True)
# Out:
# C:\Users\berka\AppData\Local\Temp\ipykernel_13516\3270601401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['height','weight'],axis=1,inplace=True)

# %%
df
# Out:
#          age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0      18393       2    110     80            1     1      0     0       1
# 1      20228       1    140     90            3     1      0     0       1
# 2      18857       1    130     70            3     1      0     0       0
# 3      17623       2    150    100            1     1      0     0       1
# 4      17474       1    100     60            1     1      0     0       0
# ...      ...     ...    ...    ...          ...   ...    ...   ...     ...
# 69995  19240       2    120     80            1     1      1     0       1
# 69996  22601       1    140     90            2     2      0     0       1
# 69997  19066       2    180     90            3     1      0     1       0
# 69998  22431       1    135     80            1     2      0     0       0
# 69999  20540       1    120     80            2     1      0     0       1
#
#        cardio   bmi
# 0           0  22.0
# 1           1  34.9
# ...

# %%
# ap_hi ve ap_lo için sırasıyla 250 ve 200den büyük değerleri almicaz. Çünkü gereksiz aşırı büyüktür.
#Aynı şekilde 20den küçükleride almicaz.

df = df[(df['ap_hi']<250) & (df['ap_lo']<200)]
df = df[(df['ap_hi']>20) & (df['ap_lo']>20)]

# Age  kolonu gün olarak tutulmuş. 365'e bölerek yıl olarak alıcaz

df['age'] = df['age'] / 365

# %%
df.head()
# Out:
#          age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0  50.391781       2    110     80            1     1      0     0       1
# 1  55.419178       1    140     90            3     1      0     0       1
# 2  51.663014       1    130     70            3     1      0     0       0
# 3  48.282192       2    150    100            1     1      0     0       1
# 4  47.873973       1    100     60            1     1      0     0       0
#
#    cardio   bmi
# 0       0  22.0
# 1       1  34.9
# 2       1  23.5
# 3       1  28.7
# 4       0  23.0

# %%
df
# Out:
#              age  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0      50.391781       2    110     80            1     1      0     0
# 1      55.419178       1    140     90            3     1      0     0
# 2      51.663014       1    130     70            3     1      0     0
# 3      48.282192       2    150    100            1     1      0     0
# 4      47.873973       1    100     60            1     1      0     0
# ...          ...     ...    ...    ...          ...   ...    ...   ...
# 69995  52.712329       2    120     80            1     1      1     0
# 69996  61.920548       1    140     90            2     2      0     0
# 69997  52.235616       2    180     90            3     1      0     1
# 69998  61.454795       1    135     80            1     2      0     0
# 69999  56.273973       1    120     80            2     1      0     0
#
#        active  cardio   bmi
# 0           1       0  22.0
# 1           1       1  34.9
# ...

# %%
df['cholesterol'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
#one hot encoding uygulayacağız

# %%
df['cholesterol'] = df['cholesterol'].map({ 1: 'normal', 2: 'aboveNormal', 3: 'wellAboveNormal'})
df['gluc']=df['gluc'].map({ 1: 'normal', 2: 'aboveNormal', 3: 'wellAboveNormal'})

dummies = pd.get_dummies(df[['cholesterol','gluc']])


final_df = pd.concat([df,dummies],axis=1)
final_df.drop(['cholesterol','gluc'],axis=1,inplace=True)
final_df.head()
# Out:
#          age  gender  ap_hi  ap_lo  smoke  alco  active  cardio   bmi  \
# 0  50.391781       2    110     80      0     0       1       0  22.0
# 1  55.419178       1    140     90      0     0       1       1  34.9
# 2  51.663014       1    130     70      0     0       0       1  23.5
# 3  48.282192       2    150    100      0     0       1       1  28.7
# 4  47.873973       1    100     60      0     0       0       0  23.0
#
#    cholesterol_aboveNormal  cholesterol_normal  cholesterol_wellAboveNormal  \
# 0                        0                   1                            0
# 1                        0                   0                            1
# 2                        0                   0                            1
# 3                        0                   1                            0
# 4                        0                   1                            0
#
#    gluc_aboveNormal  gluc_normal  gluc_wellAboveNormal
# ...

# %%
df
# Out:
#              age  gender  ap_hi  ap_lo      cholesterol         gluc  smoke  \
# 0      50.391781       2    110     80           normal       normal      0
# 1      55.419178       1    140     90  wellAboveNormal       normal      0
# 2      51.663014       1    130     70  wellAboveNormal       normal      0
# 3      48.282192       2    150    100           normal       normal      0
# 4      47.873973       1    100     60           normal       normal      0
# ...          ...     ...    ...    ...              ...          ...    ...
# 69995  52.712329       2    120     80           normal       normal      1
# 69996  61.920548       1    140     90      aboveNormal  aboveNormal      0
# 69997  52.235616       2    180     90  wellAboveNormal       normal      0
# 69998  61.454795       1    135     80           normal  aboveNormal      0
# 69999  56.273973       1    120     80      aboveNormal       normal      0
#
#        alco  active  cardio   bmi
# ...

# %%
final_df["gender"] = final_df["gender"] % 2

# %%
from sklearn.model_selection import train_test_split

y = final_df['cardio']
X = final_df.drop('cardio',axis=1)

X_train , X_test , y_train, y_test = train_test_split(X,y,test_size = 0.3 ,random_state=17)

# %%
X_train.shape
# Out:
# (48107, 14)

# %%
X_test.shape
# Out:
# (20618, 14)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

lr.fit(X_train,y_train)

y_pred = pd.Series(lr.predict(X_test))

accuracy_score(y_test,y_pred)
# Out:
# D:\anaconda\envs\yapay_zeka\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7209234649335532
